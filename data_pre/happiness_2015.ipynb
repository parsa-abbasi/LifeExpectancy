# %%
import pandas as pd
df=pd.read_csv('happines1984_2015.csv')
df.head(20)
# Out:
#         Entity Code  Year  \
# 0      Albania  ALB  1998
# 1      Albania  ALB  2004
# 2      Algeria  DZA  2004
# 3      Algeria  DZA  2014
# 4      Andorra  AND  2009
# 5    Argentina  ARG  1984
# 6    Argentina  ARG  1993
# 7    Argentina  ARG  1998
# 8    Argentina  ARG  2004
# 9    Argentina  ARG  2009
# 10   Argentina  ARG  2014
# 11     Armenia  ARM  1998
# 12     Armenia  ARM  2014
# 13   Australia  AUS  1984
# 14   Australia  AUS  1998
# 15   Australia  AUS  2009
# 16   Australia  AUS  2014
# 17  Azerbaijan  AZE  1998
# 18  Azerbaijan  AZE  2014
# 19     Bahrain  BHR  2014
#
#     Share of people who are happy (World Value Survey 2014)
# 0                                           33.433434
# 1                                           58.799999
# 2                                           80.733231
# 3                                           79.894180
# 4                                           92.878632
# 5                                           78.571426
# ...

# %%
clms={'Entity':'Region','Share of people who are happy (World Value Survey 2014)':'Rate'}
df.rename(columns=clms,inplace=True)
df.head()
# Out:
#     region Code  Year       rate
# 0  Albania  ALB  1998  33.433434
# 1  Albania  ALB  2004  58.799999
# 2  Algeria  DZA  2004  80.733231
# 3  Algeria  DZA  2014  79.894180
# 4  Andorra  AND  2009  92.878632

# %%
df.to_csv('happiness_2015.csv')
