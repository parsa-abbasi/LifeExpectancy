# %% [markdown]
# تمیزکاری آمارخودکشی تا سال 2019 ، بعضی کشورا دیتا ندارن

# %%
import pandas as pd 
scd=pd.read_csv('Suicide.csv')
scd.head(-10)
# Out:
#       IndicatorCode                                     Indicator ValueType  \
# 0        SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 1        SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 2        SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 3        SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 4        SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# ...             ...                                           ...       ...
# 17004    SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 17005    SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 17006    SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 17007    SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 17008    SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
#
# ...

# %%
drop_clm=['IndicatorCode','Indicator','ValueType','Period type','FactValueUoM','FactValueNumericLowPrefix','FactValueNumericLow',
         'FactValueNumericHighPrefix','FactValueNumericHigh','FactValueUoM','FactComments','Language','DateModified',
          'Dim1ValueCode','Dim3 type','Dim3','Dim3ValueCode','DataSourceDimValueCode','DataSource','FactValueTranslationID',
          'Dim1 type','Dim1','Dim2 type','FactValueNumericPrefix','Value','IsLatestYear','Dim2']
scd.drop(columns=drop_clm,inplace=True)
scd.head()
# Out:
#   ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AMR       Americas       Country                 ATG
# 1                AMR       Americas       Country                 ATG
# 2                AMR       Americas       Country                 ATG
# 3                AMR       Americas       Country                 ATG
# 4                AMR       Americas       Country                 ATG
#
#               Location  Period Dim2ValueCode  FactValueNumeric
# 0  Antigua and Barbuda    2019    YEARS15-19               0.0
# 1  Antigua and Barbuda    2019    YEARS15-24               0.0
# 2  Antigua and Barbuda    2019    YEARS15-29               0.0
# 3  Antigua and Barbuda    2019    YEARS25-34               0.0
# 4  Antigua and Barbuda    2019    YEARS30-49               0.0

# %% [markdown]
# برای هر دو مقدار جتسیتی میباشد ، و در بازه سنی که در جدول آمده

# %%
Clm_rename={'Period':'Year','Dim2ValueCode':'Age','FactValueNumeric':'Value'}
scd.rename(columns=Clm_rename,inplace=True)

# %%
scd.to_csv('Suicide2019.csv')
